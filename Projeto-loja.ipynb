# %%
# Importando Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leitura dos arquivos
df1 = pd.read_excel ("/content/drive/MyDrive/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Aracaju.xlsx")
df2 = pd.read_excel ("/content/drive/MyDrive/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Fortaleza.xlsx")
df3 = pd.read_excel ("/content/drive/MyDrive/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Natal.xlsx")
df4 = pd.read_excel ("/content/drive/MyDrive/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Recife.xlsx")
df5 = pd.read_excel ("/content/drive/MyDrive/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Salvador.xlsx")

# %%
# Juntando todos os arquivos
df = pd.concat([df1,df2,df3,df4,df5])

# %%
# Exibindo o DataFrame
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alterando o tipo de dado da coluna LojaID
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
# Consultando dados faltates
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 100      Natal 2019-01-02  190.97   1036     2
# 75    Salvador 2019-01-01  155.52   1034     1
# 138  Fortaleza 2019-03-02  150.38    983     6
# 181      Natal 2019-01-02  244.83   1037     2
# 231   Salvador 2019-01-03   89.85   1034     2
# 129  Fortaleza 2019-03-02   35.34    982     7
# 26      Recife 2019-01-01  126.05    980     1
# 87       Natal 2019-01-02  135.19   1034     2
# 96      Recife 2019-01-01  165.36    982     7
# 109   Salvador 2019-03-02  124.37   1035     1
# 77    Salvador 2019-01-01  218.76   1037     1
# 12   Fortaleza 2019-01-01   80.73   1004     2
# 6        Natal 2018-07-02  322.00    852     4
# 33    Salvador 2019-01-01  144.19   1035     2
# 105   Salvador 2019-01-01   32.83   1037     1

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485438

# %%
#Criando colunas novas

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita/Vendas"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00             1.0
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26             6.0
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55             1.0
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07             7.0
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08             8.0

# %%
#Retornar a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
#Retornar a menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
# Retornar maior venda
df["Vendas"].max()
# Out:
# 886.0

# %%
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0

# %%
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34             1.0
# 65    Recife 2019-01-01    4.01    981     1     4.01             1.0
# 92     Natal 2019-01-02    4.57   1035     1     4.57             1.0

# %%
#Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
#Ordenando os conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0             4.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0             4.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0             4.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0             4.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0             4.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0             4.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0             4.0

# %%
#Trabalhando com datas

# %%
# Transformando a coluna data em tipo inteiro
df["Data"] = df["Data"].astype("int64")

# %%
#Verificando os dados
df.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# Receita/Vendas    float64
# dtype: object

# %%
#Transformando a coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
#Agrupamento das receitas por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
#Criando uma nova coluna com o ano
df["Ano_Vendas"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  Receita  Receita/Vendas  Ano_Vendas
# 53       Natal 2019-02-14  290.00  ...  1160.00             4.0        2019
# 66      Recife 2019-01-01   14.59  ...   102.13             7.0        2019
# 37       Natal 2018-10-03  726.00  ...  1452.00             2.0        2018
# 22   Fortaleza 2019-01-01  150.32  ...   150.32             1.0        2019
# 144      Natal 2019-01-02   23.38  ...    23.38             1.0        2019
#
# [5 rows x 8 columns]

# %%
#Extraindo o mês e o dia
df["mes_vendas"], df["dia_vendas"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ... Ano_Vendas  mes_vendas  dia_vendas
# 186   Salvador 2019-01-02  169.09  ...       2019           1           2
# 64    Salvador 2019-01-01   37.96  ...       2019           1           1
# 116     Recife 2019-03-02   79.10  ...       2019           3           2
# 82      Recife 2019-01-01   29.55  ...       2019           1           1
# 5    Fortaleza 2019-01-01   37.30  ...       2019           1           1
#
# [5 rows x 10 columns]

# %%
#Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
#Calculando a diferença de dias
df ["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ... mes_vendas  dia_vendas  diferenca_dias
# 172   Salvador 2019-01-02    6.70  ...          1           2        366 days
# 90      Recife 2019-01-01   16.04  ...          1           1        365 days
# 119  Fortaleza 2019-03-02  152.30  ...          3           2        425 days
# 178      Natal 2019-01-02   39.28  ...          1           2        366 days
# 200      Natal 2019-01-02   41.06  ...          1           2        366 days
#
# [5 rows x 11 columns]

# %%
#Criando a coluna de trimestre
df["semestre_vendas"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ... dia_vendas  diferenca_dias  semestre_vendas
# 122    Aracaju 2018-01-01   38.49  ...          1          0 days                1
# 58       Natal 2018-12-23  272.00  ...         23        356 days                4
# 48    Salvador 2019-01-01  127.28  ...          1        365 days                1
# 128  Fortaleza 2019-03-02   38.70  ...          2        425 days                1
# 145      Natal 2019-01-02   84.62  ...          2        366 days                1
#
# [5 rows x 12 columns]

# %%
#Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year ==2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas  ... dia_vendas  diferenca_dias  semestre_vendas
# 108  Fortaleza 2019-03-02  152.89  ...          2        425 days                1
# 109  Fortaleza 2019-03-02   18.90  ...          2        425 days                1
# 110  Fortaleza 2019-03-02   51.98  ...          2        425 days                1
# 111  Fortaleza 2019-03-02    8.00  ...          2        425 days                1
# 112  Fortaleza 2019-03-02  133.59  ...          2        425 days                1
# ..         ...        ...     ...  ...        ...             ...              ...
# 137   Salvador 2019-03-02   51.66  ...          2        425 days                1
# 138   Salvador 2019-03-02  212.03  ...          2        425 days                1
# 139   Salvador 2019-03-02  169.01  ...          2        425 days                1
# 140   Salvador 2019-03-02   20.79  ...          2        425 days                1
# ...

# %%
## Visuaização de dados

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1002     30
# 1005     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
#Gráficos de barras 
df['LojaID'].value_counts(ascending=False).plot.bar()

# %%
#Gráfico de barras horizontais
df['LojaID'].value_counts(ascending=True).plot.barh()

# %%
#Gráfico de pizza anual da receita
df.groupby(df["Data"].dt.year)['Receita'].sum().plot.pie()

# %%
#Total de vendas por cidades
df["Cidade"].value_counts().plot.bar()

# %%
#Adicionado títulos e alterando o nome dos eixos 
df["Cidade"].value_counts().plot.bar(title="Total vendas por cidades")
plt.xlabel("Cidades")
plt.ylabel("Total de Vendas");

# %%
#Alterar cor
df["Cidade"].value_counts().plot.bar(title="Total vendas por cdades", color="red")
plt.xlabel("Cidades")
plt.ylabel("Total de Vendas");

# %%
#Alterando o estilo
plt.style.use("ggplot")

# %%
df.groupby(["mes_vendas"])["Qtde"].sum().plot()
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend()

# %%
df.groupby(df["mes_vendas"])["Qtde"].sum()
# Out:
# mes_vendas
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
#Selecionar apenas as vendas de 2019
df_2019 = df[df['Ano_Vendas']==2019]

# %%
#Total de produtos vendidos por mês
df_2019.groupby(df_2019["mes_vendas"])['Qtde'].sum().plot(marker = "v")
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos");
plt.legend()

# %%
#Histograma
plt.hist(df["Qtde"], color="aqua")
# Out:
# (array([191., 193., 221.,  85.,  54.,  61.,  38.,  31.,  14.,   6.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(x=df_2019["dia_vendas"], y=df_2019["Receita"]);

# %%
#Salvando o DataFrame em png
df_2019.groupby(df_2019["mes_vendas"])["Qtde"].sum().plot(marker = "v")
plt.title("Qauntidade de produtos vendidos x mês")
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos");
plt.legend()
plt.savefig("gráfico QTDE x MÊS.png")
